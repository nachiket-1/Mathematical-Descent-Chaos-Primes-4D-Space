# %%
from IPython.display import HTML, display
display(HTML('''<link href="https://fonts.googleapis.com/css2?family=Orbitron:wght@400;700;900&family=Share+Tech+Mono&family=Bebas+Neue&display=swap" rel="stylesheet"><style>
@keyframes gpan{0%{background-position:0% 50%}50%{background-position:100% 50%}100%{background-position:0% 50%}}
@keyframes glitch1{0%,88%,100%{clip-path:none;transform:none}89%{clip-path:polygon(0 10%,100% 10%,100% 28%,0 28%);transform:translateX(-5px);filter:hue-rotate(80deg) brightness(2)}91%{clip-path:polygon(0 55%,100% 55%,100% 72%,0 72%);transform:translateX(5px);filter:hue-rotate(-50deg)}93%{clip-path:none;transform:none;filter:none}}
@keyframes glitch2{0%,93%,100%{opacity:0}90%{opacity:.9;transform:translateX(8px);filter:hue-rotate(200deg)}92%{opacity:.4;transform:translateX(-8px)}}
@keyframes scan{0%{transform:translateY(-100%)}100%{transform:translateY(120vh)}}
@keyframes ptag{0%,100%{box-shadow:0 0 8px currentColor;opacity:.7}50%{box-shadow:0 0 24px currentColor,0 0 50px currentColor;opacity:1}}
@keyframes flkr{0%,95%,100%{opacity:1}96%{opacity:.1}97%{opacity:.8}}
@keyframes flt{0%,100%{transform:translateY(0)}50%{transform:translateY(-10px)}}
@keyframes spinr{from{transform:rotate(0)}to{transform:rotate(360deg)}}
@keyframes spini{from{transform:rotate(0)}to{transform:rotate(-360deg)}}
</style>
<div style="position:relative;background:#03020a;padding:36px 40px 30px;border-radius:16px;
  border:1px solid #3a86ff22;box-shadow:0 0 60px #3a86ff10;overflow:hidden;margin-bottom:8px;">
  <div style="position:absolute;inset:0;pointer-events:none;
    background-image:linear-gradient(#3a86ff07 1px,transparent 1px),
      linear-gradient(90deg,#3a86ff07 1px,transparent 1px);
    background-size:44px 44px;"></div>
  <div style="position:absolute;left:0;top:0;bottom:0;width:4px;
    background:linear-gradient(180deg,transparent,#3a86ff,#3a86ff88,transparent);
    box-shadow:0 0 16px #3a86ff;"></div>
  <div style="padding-left:20px;">
    <div style="font-family:'Share Tech Mono',monospace;font-size:9px;letter-spacing:7px;
      color:#3a86ff60;text-transform:uppercase;margin-bottom:8px;">
      IMPOSSIBLE GEOMETRY &nbsp;&#183;&nbsp; SECTION 04</div>
    <h1 style="font-family:'Orbitron',sans-serif;font-size:clamp(20px,2.5vw,32px);font-weight:900;
      letter-spacing:3px;margin:0;line-height:1.2;
      background:linear-gradient(90deg,#3a86ff,#ffffff,#3a86ff);
      background-size:200% 100%;-webkit-background-clip:text;-webkit-text-fill-color:transparent;
      background-clip:text;animation:gpan 5s ease infinite;">4D TESSERACT — ANIMATED</h1>
  </div>
</div>'''))

# %%
from IPython.display import HTML, display
display(HTML('''<link href="https://fonts.googleapis.com/css2?family=Orbitron:wght@400;700;900&family=Share+Tech+Mono&family=Bebas+Neue&display=swap" rel="stylesheet">
<style>
@keyframes numglow-tc{0%,100%{opacity:.1;text-shadow:none}50%{opacity:.42;text-shadow:0 0 80px #3a86ff}}
@keyframes secin-tc{from{opacity:0;transform:translateX(-30px)}to{opacity:1;transform:translateX(0)}}
@keyframes bscan-tc{0%{transform:translateY(-100%)}100%{transform:translateY(500px)}}
@keyframes linefill-tc{from{width:0}to{width:100%}}
@keyframes gpan{0%{background-position:0% 50%}50%{background-position:100% 50%}100%{background-position:0% 50%}}
@keyframes ptag{0%,100%{box-shadow:0 0 8px currentColor;opacity:.7}50%{box-shadow:0 0 24px currentColor;opacity:1}}
</style>
<div style="position:relative;margin:52px 0 0;overflow:visible;">
  <div style="position:absolute;top:-28px;right:16px;z-index:0;pointer-events:none;user-select:none;
    font-family:'Bebas Neue',sans-serif;font-size:190px;line-height:1;color:#3a86ff;letter-spacing:-4px;
    animation:numglow-tc 4s ease-in-out infinite;">04</div>
  <div style="position:relative;z-index:1;
    background:linear-gradient(110deg,rgba(0,0,0,.92),rgba(8,3,20,.96) 50%,rgba(0,0,0,.85));
    border:1px solid #3a86ff30;border-radius:4px 20px 20px 4px;
    padding:36px 200px 36px 0;overflow:hidden;
    box-shadow:0 0 60px #3a86ff16,inset 0 0 80px rgba(0,0,0,.6);">
    <div style="position:absolute;left:0;top:0;bottom:0;width:6px;
      background:linear-gradient(180deg,#80b8ff,#3a86ff,#80b8ff);
      box-shadow:0 0 20px #3a86ff,0 0 40px #3a86ff88;"></div>
    <div style="position:absolute;left:6px;right:0;height:1px;pointer-events:none;
      background:linear-gradient(90deg,#3a86ff77,transparent);
      animation:bscan-tc 4.5s linear infinite;"></div>
    <div style="position:absolute;top:0;left:6px;height:1px;
      background:linear-gradient(90deg,#3a86ff55,transparent);
      animation:linefill-tc 1.3s ease both;"></div>
    <div style="padding-left:36px;">
      <div style="font-family:'Share Tech Mono',monospace;font-size:10px;letter-spacing:6px;
        color:#3a86ff80;text-transform:uppercase;margin-bottom:10px;
        animation:secin-tc .8s ease both;">SECTION &nbsp;04</div>
      <h2 style="font-family:'Orbitron',sans-serif;font-size:clamp(22px,3vw,36px);font-weight:900;
        letter-spacing:4px;margin:0 0 8px;line-height:1.15;
        background:linear-gradient(90deg,#3a86ff,#80b8ff,#ffffff,#3a86ff);
        background-size:250% 100%;-webkit-background-clip:text;-webkit-text-fill-color:transparent;
        background-clip:text;animation:gpan 6s ease infinite,secin-tc .9s ease both;">
        4D TESSERACT — ANIMATED</h2>
      <p style="font-family:'Share Tech Mono',monospace;font-size:11px;letter-spacing:3px;
        color:rgba(210,190,255,.4);text-transform:uppercase;margin:0 0 20px;
        animation:secin-tc 1s ease both;">a hypercube rotating simultaneously in the XW and YZ planes</p>
      <div style="display:flex;flex-wrap:wrap;"><span style="font-family:'Share Tech Mono',monospace;font-size:9px;letter-spacing:2px;padding:4px 13px;border-radius:100px;border:1px solid #3a86ff99;color:#3a86ff;text-transform:uppercase;display:inline-block;margin:3px;">4D Geometry</span><span style="font-family:'Share Tech Mono',monospace;font-size:9px;letter-spacing:2px;padding:4px 13px;border-radius:100px;border:1px solid #3a86ff99;color:#3a86ff;text-transform:uppercase;display:inline-block;margin:3px;">Dual Projection</span><span style="font-family:'Share Tech Mono',monospace;font-size:9px;letter-spacing:2px;padding:4px 13px;border-radius:100px;border:1px solid #3a86ff99;color:#3a86ff;text-transform:uppercase;display:inline-block;margin:3px;">Quasiperiodic Rotation</span><span style="font-family:'Share Tech Mono',monospace;font-size:9px;letter-spacing:2px;padding:4px 13px;border-radius:100px;border:1px solid #3a86ff99;color:#3a86ff;text-transform:uppercase;display:inline-block;margin:3px;">Higher Dimensions</span></div>
    </div>
  </div>
</div>'''))

# %%
from IPython.display import HTML, display
display(HTML('''<link href="https://fonts.googleapis.com/css2?family=Orbitron:wght@400;700;900&family=Share+Tech+Mono&family=Bebas+Neue&display=swap" rel="stylesheet">
<style>
@keyframes panelglow-tc{0%,100%{box-shadow:0 0 30px #3a86ff16,inset 0 0 40px rgba(0,0,0,.4)}
  50%{box-shadow:0 0 55px #3a86ff28,inset 0 0 55px rgba(0,0,0,.6)}}
@keyframes shimmer-tc{0%{left:-100%}100%{left:200%}}
</style>
<div style="position:relative;margin:16px 0 32px;overflow:hidden;
  background:linear-gradient(135deg,#07041a,#04020e 40%,#060320);
  border:1px solid #3a86ff1e;border-radius:16px;padding:38px 36px 32px;
  animation:panelglow-tc 5s ease-in-out infinite;">
  <div style="position:absolute;top:0;left:-100%;width:60%;height:1px;pointer-events:none;
    background:linear-gradient(90deg,transparent,#3a86ffbb,transparent);
    animation:shimmer-tc 5s ease-in-out infinite;"></div>
  <div style="position:absolute;top:14px;left:14px;width:22px;height:22px;
    border-top:2px solid #3a86ff88;border-left:2px solid #3a86ff88;border-radius:3px 0 0 0;"></div>
  <div style="position:absolute;top:14px;right:14px;width:22px;height:22px;
    border-top:2px solid #3a86ff88;border-right:2px solid #3a86ff88;border-radius:0 3px 0 0;"></div>
  <div style="position:absolute;bottom:14px;left:14px;width:22px;height:22px;
    border-bottom:2px solid #3a86ff44;border-left:2px solid #3a86ff44;border-radius:0 0 0 3px;"></div>
  <div style="position:absolute;bottom:14px;right:14px;width:22px;height:22px;
    border-bottom:2px solid #3a86ff44;border-right:2px solid #3a86ff44;border-radius:0 0 3px 0;"></div>
  <div style="position:absolute;top:-1px;left:50%;transform:translateX(-50%);
    background:#07041a;border:1px solid #3a86ff33;border-top:none;
    padding:0 18px 5px;border-radius:0 0 8px 8px;">
    <span style="font-family:'Share Tech Mono',monospace;font-size:9px;letter-spacing:4px;
      color:#3a86ff77;text-transform:uppercase;">&#9654; what is actually happening &#9664;</span>
  </div>
  <div style="margin-top:16px;">
    <div style="margin-bottom:30px;">
      <div style="display:flex;align-items:center;gap:12px;margin-bottom:14px;">
        <span style="font-size:18px;">📦</span>
        <div style="flex:1;height:1px;background:linear-gradient(90deg,#3a86ff44,transparent);"></div>
        <span style="font-family:'Orbitron',sans-serif;font-size:10px;font-weight:700;
          color:#3a86ff;letter-spacing:3px;text-transform:uppercase;">Building from 1D to 4D</span>
        <div style="flex:1;height:1px;background:linear-gradient(270deg,#3a86ff44,transparent);"></div>
      </div>
      <div style="font-family:'Share Tech Mono',monospace;font-size:13px;
        color:rgba(210,195,255,.68);line-height:2;">Line → Square → Cube → <strong style='color:#3a86ff;'>Tesseract</strong>. Each step: duplicate and connect corresponding corners.<table style="width:100%;border-collapse:collapse;margin:14px 0;font-size:12px;font-family:monospace;"><tr><th style="padding:5px 10px;text-align:left;color:#3a86ff;border-bottom:1px solid #3a86ff33;font-size:10px;letter-spacing:2px;">DIM</th><th style="padding:5px 10px;text-align:left;color:#3a86ff;border-bottom:1px solid #3a86ff33;font-size:10px;letter-spacing:2px;">NAME</th><th style="padding:5px 10px;text-align:left;color:#3a86ff;border-bottom:1px solid #3a86ff33;font-size:10px;letter-spacing:2px;">VERTICES</th><th style="padding:5px 10px;text-align:left;color:#3a86ff;border-bottom:1px solid #3a86ff33;font-size:10px;letter-spacing:2px;">EDGES</th><th style="padding:5px 10px;text-align:left;color:#3a86ff;border-bottom:1px solid #3a86ff33;font-size:10px;letter-spacing:2px;">FACES</th><th style="padding:5px 10px;text-align:left;color:#3a86ff;border-bottom:1px solid #3a86ff33;font-size:10px;letter-spacing:2px;">3-CELLS</th></tr><tr><td style="padding:5px 10px;color:rgba(210,195,255,.65);border-bottom:1px solid #3a86ff11;">1D</td><td style="padding:5px 10px;color:rgba(210,195,255,.65);border-bottom:1px solid #3a86ff11;">Line segment</td><td style="padding:5px 10px;color:rgba(210,195,255,.65);border-bottom:1px solid #3a86ff11;">2</td><td style="padding:5px 10px;color:rgba(210,195,255,.65);border-bottom:1px solid #3a86ff11;">1</td><td style="padding:5px 10px;color:rgba(210,195,255,.65);border-bottom:1px solid #3a86ff11;">—</td><td style="padding:5px 10px;color:rgba(210,195,255,.65);border-bottom:1px solid #3a86ff11;">—</td></tr><tr><td style="padding:5px 10px;color:rgba(210,195,255,.65);border-bottom:1px solid #3a86ff11;">2D</td><td style="padding:5px 10px;color:rgba(210,195,255,.65);border-bottom:1px solid #3a86ff11;">Square</td><td style="padding:5px 10px;color:rgba(210,195,255,.65);border-bottom:1px solid #3a86ff11;">4</td><td style="padding:5px 10px;color:rgba(210,195,255,.65);border-bottom:1px solid #3a86ff11;">4</td><td style="padding:5px 10px;color:rgba(210,195,255,.65);border-bottom:1px solid #3a86ff11;">1</td><td style="padding:5px 10px;color:rgba(210,195,255,.65);border-bottom:1px solid #3a86ff11;">—</td></tr><tr><td style="padding:5px 10px;color:rgba(210,195,255,.65);border-bottom:1px solid #3a86ff11;">3D</td><td style="padding:5px 10px;color:rgba(210,195,255,.65);border-bottom:1px solid #3a86ff11;">Cube</td><td style="padding:5px 10px;color:rgba(210,195,255,.65);border-bottom:1px solid #3a86ff11;">8</td><td style="padding:5px 10px;color:rgba(210,195,255,.65);border-bottom:1px solid #3a86ff11;">12</td><td style="padding:5px 10px;color:rgba(210,195,255,.65);border-bottom:1px solid #3a86ff11;">6</td><td style="padding:5px 10px;color:rgba(210,195,255,.65);border-bottom:1px solid #3a86ff11;">1</td></tr><tr><td style="padding:5px 10px;color:#3a86ff;font-weight:bold;">4D</td><td style="padding:5px 10px;color:#3a86ff;font-weight:bold;">Tesseract</td><td style="padding:5px 10px;color:#3a86ff;font-weight:bold;">16</td><td style="padding:5px 10px;color:#3a86ff;font-weight:bold;">32</td><td style="padding:5px 10px;color:#3a86ff;font-weight:bold;">24</td><td style="padding:5px 10px;color:#3a86ff;font-weight:bold;">8 full cubes</td></tr></table>All eight cubic cells are the <strong style='color:#3a86ff;'>same size in 4D</strong>. They only appear distorted because of the projection.</div>
    </div>
    <div style="margin-bottom:30px;">
      <div style="display:flex;align-items:center;gap:12px;margin-bottom:14px;">
        <span style="font-size:18px;">🔄</span>
        <div style="flex:1;height:1px;background:linear-gradient(90deg,#3a86ff44,transparent);"></div>
        <span style="font-family:'Orbitron',sans-serif;font-size:10px;font-weight:700;
          color:#3a86ff;letter-spacing:3px;text-transform:uppercase;">How the 4D Rotation Works</span>
        <div style="flex:1;height:1px;background:linear-gradient(270deg,#3a86ff44,transparent);"></div>
      </div>
      <div style="font-family:'Share Tech Mono',monospace;font-size:13px;
        color:rgba(210,195,255,.68);line-height:2;">In 3D: 3 rotation planes. In 4D: <strong style='color:#3a86ff;'>six planes</strong> (XY,XZ,XW,YZ,YW,ZW). This animation applies two simultaneously:<div style="background:#3a86ff0d;border-left:3px solid #3a86ff;border-radius:0 8px 8px 0;padding:12px 18px;margin:12px 0;font-size:13.5px;color:#3a86ff;letter-spacing:.5px;line-height:2.1;">R₁: XW-plane at rate t  (mixes X and W)<br>R₂: YZ-plane at rate 1.3t  (mixes Y and Z)<br>Combined: R = R₂ · R₁  applied to all 16 vertices at once</div>Speeds 1.0 and 1.3 are incommensurable — the animation traces a <strong style='color:#3a86ff;'>dense set of orientations</strong>, never exactly repeating.</div>
    </div>
    <div style="margin-bottom:0px;">
      <div style="display:flex;align-items:center;gap:12px;margin-bottom:14px;">
        <span style="font-size:18px;">👁️</span>
        <div style="flex:1;height:1px;background:linear-gradient(90deg,#3a86ff44,transparent);"></div>
        <span style="font-family:'Orbitron',sans-serif;font-size:10px;font-weight:700;
          color:#3a86ff;letter-spacing:3px;text-transform:uppercase;">The Double Projection & The Popping Mystery</span>
        <div style="flex:1;height:1px;background:linear-gradient(270deg,#3a86ff44,transparent);"></div>
      </div>
      <div style="font-family:'Share Tech Mono',monospace;font-size:13px;
        color:rgba(210,195,255,.68);line-height:2;"><strong style='color:#3a86ff;'>Stage 1:</strong> 4D perspective divide on W — points farther in W appear smaller, producing the inner/outer cube illusion. <strong style='color:#3a86ff;'>Stage 2:</strong> orthographic drop of Z — 3D → 2D.<br><br>The inner cube popping through the outer is not a glitch. In 4D those cells connect differently — as different cubic cells rotate to the front of W, their projected sizes exchange. In 4D it is smooth.<div style="background:#3a86ff09;border:1px solid #3a86ff28;border-radius:10px;padding:14px 18px;margin-top:14px;font-size:12px;color:rgba(220,210,255,.6);line-height:1.95;"><span style="color:#3a86ff;font-weight:bold;">&#9670;</span> The confusion you feel is geometrically accurate. Your brain evolved to parse 3D. Every time it locks on to a 3D interpretation the rotation invalidates it. That oscillating confusion is what 4D rotation looks like from inside a 3D brain.</div></div>
    </div></div>
</div>'''))

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
from matplotlib import animation
from IPython.display import HTML, display
import warnings; warnings.filterwarnings('ignore')

plt.rcParams.update({
    'figure.facecolor':'#03020a','axes.facecolor':'#03020a',
    'axes.edgecolor':'#1a0a30','text.color':'#c8b8ff',
    'axes.labelcolor':'#c8b8ff','xtick.color':'#5030a0',
    'ytick.color':'#5030a0','font.family':'monospace'
})

# %%
verts4=np.array([[x,y,z,w] for x in(-1,1) for y in(-1,1) for z in(-1,1) for w in(-1,1)],dtype=float)
edges=[(i,j) for i in range(16) for j in range(i+1,16) if np.sum(verts4[i]!=verts4[j])==1]
print(f"Tesseract: {len(verts4)} vertices, {len(edges)} edges")

def rot4d(t):
    c1,s1=np.cos(t),np.sin(t); c2,s2=np.cos(t*1.3),np.sin(t*1.3)
    Rxw=np.array([[c1,0,0,s1],[0,1,0,0],[0,0,1,0],[-s1,0,0,c1]])
    Ryz=np.array([[1,0,0,0],[0,c2,s2,0],[0,-s2,c2,0],[0,0,0,1]])
    return Ryz@Rxw

def project(v,dist=3.5):
    pts=v.copy(); w=pts[:,3]; s=1./(dist-w)
    p3=pts[:,:3]*s[:,None]; return p3[:,:2],p3[:,2]

FRAMES=90
fig,ax=plt.subplots(figsize=(9,9),facecolor='#03020a')
ax.set_facecolor('#03020a'); ax.set_aspect('equal'); ax.axis('off')
ax.set_xlim(-2.2,2.2); ax.set_ylim(-2.2,2.2)
ax.set_title("4D TESSERACT  ·  Simultaneous XW × YZ rotation\nEdge brightness = depth after 4D→3D projection",
             color='#3a86ff',fontsize=11,pad=10)
lo=[ax.plot([],[],lw=1.2,alpha=0.)[0] for _ in edges]
do=[ax.plot([],[],'o',ms=4,alpha=0.)[0] for _ in range(16)]

def init():
    [l.set_data([],[]) for l in lo]; [d.set_data([],[]) for d in do]; return lo+do

def upd(f):
    t=f/FRAMES*2*np.pi; R=rot4d(t); pts=(R@verts4.T).T; xy,zv=project(pts)
    dep=(zv-zv.min())/(zv.max()-zv.min()+1e-9)
    for obj,(i,j) in zip(lo,edges):
        da=(dep[i]+dep[j])/2
        obj.set_data([xy[i,0],xy[j,0]],[xy[i,1],xy[j,1]])
        obj.set_color((da*.3,da*.6,1.-da*.7)); obj.set_alpha(.35+.65*da); obj.set_linewidth(.7+1.5*da)
    for obj,k in zip(do,range(16)):
        obj.set_data([xy[k,0]],[xy[k,1]]); obj.set_color((.5+.5*dep[k],.5*dep[k],1.))
        obj.set_alpha(.6+.4*dep[k]); obj.set_markersize(3+4*dep[k])
    return lo+do

anim=animation.FuncAnimation(fig,upd,frames=FRAMES,init_func=init,interval=50,blit=True)
plt.close()
display(HTML(anim.to_jshtml(fps=20,default_mode='loop')))
print("The inner cube popping through the outer is not a glitch.")
print("In 4D those cells connect in a way no 3D analogy can capture.")

# %%
from IPython.display import HTML, display
display(HTML('''<link href="https://fonts.googleapis.com/css2?family=Orbitron:wght@400;700;900&family=Share+Tech+Mono&family=Bebas+Neue&display=swap" rel="stylesheet">
<style>
@keyframes oglow{0%,100%{text-shadow:0 0 12px #c040ff,0 0 30px #c040ff44}50%{text-shadow:0 0 40px #ff006e,0 0 90px #ff006e44}}
@keyframes oscan{0%{left:-100%}100%{left:200%}}
@keyframes cardglow{0%,100%{box-shadow:0 0 20px rgba(180,100,255,.1)}50%{box-shadow:0 0 40px rgba(180,100,255,.2)}}
@keyframes gpan{0%{background-position:0% 50%}50%{background-position:100% 50%}100%{background-position:0% 50%}}
</style>
<div style="position:relative;margin:60px 0 20px;overflow:hidden;
  background:linear-gradient(135deg,#03020a,#0a0320 55%,#03020a);
  border:1px solid rgba(120,50,255,.18);border-radius:20px;padding:60px 40px 50px;
  text-align:center;font-family:'Share Tech Mono',monospace;">
  <div style="position:absolute;inset:0;pointer-events:none;
    background-image:linear-gradient(rgba(100,40,255,.04) 1px,transparent 1px),
      linear-gradient(90deg,rgba(100,40,255,.04) 1px,transparent 1px);
    background-size:44px 44px;"></div>
  <div style="position:absolute;top:50%;left:-100%;width:50%;height:1px;pointer-events:none;
    background:linear-gradient(90deg,transparent,rgba(200,100,255,.5),transparent);
    animation:oscan 5s ease-in-out infinite;"></div>
  <div style="position:absolute;top:16px;left:16px;width:32px;height:32px;
    border-top:2px solid rgba(160,80,255,.5);border-left:2px solid rgba(160,80,255,.5);border-radius:3px 0 0 0;"></div>
  <div style="position:absolute;top:16px;right:16px;width:32px;height:32px;
    border-top:2px solid rgba(160,80,255,.5);border-right:2px solid rgba(160,80,255,.5);border-radius:0 3px 0 0;"></div>
  <div style="position:absolute;bottom:16px;left:16px;width:32px;height:32px;
    border-bottom:2px solid rgba(160,80,255,.3);border-left:2px solid rgba(160,80,255,.3);border-radius:0 0 0 3px;"></div>
  <div style="position:absolute;bottom:16px;right:16px;width:32px;height:32px;
    border-bottom:2px solid rgba(160,80,255,.3);border-right:2px solid rgba(160,80,255,.3);border-radius:0 0 3px 0;"></div>
  <h2 style="font-family:'Orbitron',sans-serif;font-size:28px;font-weight:900;color:#c040ff;
    letter-spacing:5px;animation:oglow 3s ease-in-out infinite;margin-bottom:16px;">THREE PROFOUND TRUTHS</h2>
  <p style="color:rgba(200,180,255,.5);font-size:13px;line-height:2.2;max-width:560px;margin:0 auto 40px;">
    Every structure in this notebook emerged from equations small enough to fit on a single line.<br>
    Complexity is not added &mdash; it is <em>unavoidable</em>.</p>
  <div style="display:grid;grid-template-columns:repeat(auto-fit,minmax(230px,1fr));gap:18px;margin-bottom:40px;">
    <div style="border:1px solid rgba(0,245,212,.2);border-radius:14px;padding:26px 20px;
      background:rgba(0,245,212,.04);animation:cardglow 4s ease-in-out infinite;">
      <div style="font-family:'Orbitron',sans-serif;font-size:36px;font-weight:900;
        background:linear-gradient(135deg,#00f5d4,#00aa88);-webkit-background-clip:text;
        -webkit-text-fill-color:transparent;margin-bottom:12px;">01</div>
      <div style="font-size:11px;color:rgba(200,245,220,.6);line-height:1.9;">
        Simple rules produce infinite complexity.<br>Chaos is not the absence of order —<br>it is order we cannot compress.</div>
    </div>
    <div style="border:1px solid rgba(192,64,255,.2);border-radius:14px;padding:26px 20px;
      background:rgba(192,64,255,.04);animation:cardglow 4s ease-in-out .15s infinite;">
      <div style="font-family:'Orbitron',sans-serif;font-size:36px;font-weight:900;
        background:linear-gradient(135deg,#c040ff,#7020aa);-webkit-background-clip:text;
        -webkit-text-fill-color:transparent;margin-bottom:12px;">02</div>
      <div style="font-size:11px;color:rgba(210,190,255,.6);line-height:1.9;">
        The universe has at least 4 dimensions.<br>Every object you have ever seen<br>is a shadow of something higher.</div>
    </div>
    <div style="border:1px solid rgba(255,190,11,.2);border-radius:14px;padding:26px 20px;
      background:rgba(255,190,11,.04);animation:cardglow 4s ease-in-out .3s infinite;">
      <div style="font-family:'Orbitron',sans-serif;font-size:36px;font-weight:900;
        background:linear-gradient(135deg,#ffbe0b,#aa8000);-webkit-background-clip:text;
        -webkit-text-fill-color:transparent;margin-bottom:12px;">03</div>
      <div style="font-size:11px;color:rgba(255,230,160,.6);line-height:1.9;">
        Primes are not random.<br>They obey a law no human has proved.<br>The Riemann Hypothesis still waits.</div>
    </div>
  </div>
  <div style="width:200px;height:1px;margin:0 auto 24px;
    background:linear-gradient(90deg,transparent,rgba(180,80,255,.6),transparent);"></div>
  <p style="font-size:10px;letter-spacing:5px;color:rgba(160,80,255,.3);text-transform:uppercase;margin:0;">
    &#9658; &nbsp; end of descent &nbsp; &#9668;</p>
</div>'''))
