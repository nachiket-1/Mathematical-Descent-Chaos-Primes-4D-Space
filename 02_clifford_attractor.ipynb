# %%
from IPython.display import HTML, display
display(HTML('''<link href="https://fonts.googleapis.com/css2?family=Orbitron:wght@400;700;900&family=Share+Tech+Mono&family=Bebas+Neue&display=swap" rel="stylesheet"><style>
@keyframes gpan{0%{background-position:0% 50%}50%{background-position:100% 50%}100%{background-position:0% 50%}}
@keyframes glitch1{0%,88%,100%{clip-path:none;transform:none}89%{clip-path:polygon(0 10%,100% 10%,100% 28%,0 28%);transform:translateX(-5px);filter:hue-rotate(80deg) brightness(2)}91%{clip-path:polygon(0 55%,100% 55%,100% 72%,0 72%);transform:translateX(5px);filter:hue-rotate(-50deg)}93%{clip-path:none;transform:none;filter:none}}
@keyframes glitch2{0%,93%,100%{opacity:0}90%{opacity:.9;transform:translateX(8px);filter:hue-rotate(200deg)}92%{opacity:.4;transform:translateX(-8px)}}
@keyframes scan{0%{transform:translateY(-100%)}100%{transform:translateY(120vh)}}
@keyframes ptag{0%,100%{box-shadow:0 0 8px currentColor;opacity:.7}50%{box-shadow:0 0 24px currentColor,0 0 50px currentColor;opacity:1}}
@keyframes flkr{0%,95%,100%{opacity:1}96%{opacity:.1}97%{opacity:.8}}
@keyframes flt{0%,100%{transform:translateY(0)}50%{transform:translateY(-10px)}}
@keyframes spinr{from{transform:rotate(0)}to{transform:rotate(360deg)}}
@keyframes spini{from{transform:rotate(0)}to{transform:rotate(-360deg)}}
</style>
<div style="position:relative;background:#03020a;padding:36px 40px 30px;border-radius:16px;
  border:1px solid #c040ff22;box-shadow:0 0 60px #c040ff10;overflow:hidden;margin-bottom:8px;">
  <div style="position:absolute;inset:0;pointer-events:none;
    background-image:linear-gradient(#c040ff07 1px,transparent 1px),
      linear-gradient(90deg,#c040ff07 1px,transparent 1px);
    background-size:44px 44px;"></div>
  <div style="position:absolute;left:0;top:0;bottom:0;width:4px;
    background:linear-gradient(180deg,transparent,#c040ff,#c040ff88,transparent);
    box-shadow:0 0 16px #c040ff;"></div>
  <div style="padding-left:20px;">
    <div style="font-family:'Share Tech Mono',monospace;font-size:9px;letter-spacing:7px;
      color:#c040ff60;text-transform:uppercase;margin-bottom:8px;">
      IMPOSSIBLE GEOMETRY &nbsp;&#183;&nbsp; SECTION 02</div>
    <h1 style="font-family:'Orbitron',sans-serif;font-size:clamp(20px,2.5vw,32px);font-weight:900;
      letter-spacing:3px;margin:0;line-height:1.2;
      background:linear-gradient(90deg,#c040ff,#ffffff,#c040ff);
      background-size:200% 100%;-webkit-background-clip:text;-webkit-text-fill-color:transparent;
      background-clip:text;animation:gpan 5s ease infinite;">CLIFFORD STRANGE ATTRACTOR</h1>
  </div>
</div>'''))

# %%
from IPython.display import HTML, display
display(HTML('''<link href="https://fonts.googleapis.com/css2?family=Orbitron:wght@400;700;900&family=Share+Tech+Mono&family=Bebas+Neue&display=swap" rel="stylesheet">
<style>
@keyframes numglow-cl{0%,100%{opacity:.1;text-shadow:none}50%{opacity:.42;text-shadow:0 0 80px #c040ff}}
@keyframes secin-cl{from{opacity:0;transform:translateX(-30px)}to{opacity:1;transform:translateX(0)}}
@keyframes bscan-cl{0%{transform:translateY(-100%)}100%{transform:translateY(500px)}}
@keyframes linefill-cl{from{width:0}to{width:100%}}
@keyframes gpan{0%{background-position:0% 50%}50%{background-position:100% 50%}100%{background-position:0% 50%}}
@keyframes ptag{0%,100%{box-shadow:0 0 8px currentColor;opacity:.7}50%{box-shadow:0 0 24px currentColor;opacity:1}}
</style>
<div style="position:relative;margin:52px 0 0;overflow:visible;">
  <div style="position:absolute;top:-28px;right:16px;z-index:0;pointer-events:none;user-select:none;
    font-family:'Bebas Neue',sans-serif;font-size:190px;line-height:1;color:#c040ff;letter-spacing:-4px;
    animation:numglow-cl 4s ease-in-out infinite;">02</div>
  <div style="position:relative;z-index:1;
    background:linear-gradient(110deg,rgba(0,0,0,.92),rgba(8,3,20,.96) 50%,rgba(0,0,0,.85));
    border:1px solid #c040ff30;border-radius:4px 20px 20px 4px;
    padding:36px 200px 36px 0;overflow:hidden;
    box-shadow:0 0 60px #c040ff16,inset 0 0 80px rgba(0,0,0,.6);">
    <div style="position:absolute;left:0;top:0;bottom:0;width:6px;
      background:linear-gradient(180deg,#e080ff,#c040ff,#e080ff);
      box-shadow:0 0 20px #c040ff,0 0 40px #c040ff88;"></div>
    <div style="position:absolute;left:6px;right:0;height:1px;pointer-events:none;
      background:linear-gradient(90deg,#c040ff77,transparent);
      animation:bscan-cl 4.5s linear infinite;"></div>
    <div style="position:absolute;top:0;left:6px;height:1px;
      background:linear-gradient(90deg,#c040ff55,transparent);
      animation:linefill-cl 1.3s ease both;"></div>
    <div style="padding-left:36px;">
      <div style="font-family:'Share Tech Mono',monospace;font-size:10px;letter-spacing:6px;
        color:#c040ff80;text-transform:uppercase;margin-bottom:10px;
        animation:secin-cl .8s ease both;">SECTION &nbsp;02</div>
      <h2 style="font-family:'Orbitron',sans-serif;font-size:clamp(22px,3vw,36px);font-weight:900;
        letter-spacing:4px;margin:0 0 8px;line-height:1.15;
        background:linear-gradient(90deg,#c040ff,#e080ff,#ffffff,#c040ff);
        background-size:250% 100%;-webkit-background-clip:text;-webkit-text-fill-color:transparent;
        background-clip:text;animation:gpan 6s ease infinite,secin-cl .9s ease both;">
        CLIFFORD ATTRACTOR</h2>
      <p style="font-family:'Share Tech Mono',monospace;font-size:11px;letter-spacing:3px;
        color:rgba(210,190,255,.4);text-transform:uppercase;margin:0 0 20px;
        animation:secin-cl 1s ease both;">6 million chaotic steps — painting with pure determinism</p>
      <div style="display:flex;flex-wrap:wrap;"><span style="font-family:'Share Tech Mono',monospace;font-size:9px;letter-spacing:2px;padding:4px 13px;border-radius:100px;border:1px solid #c040ff99;color:#c040ff;text-transform:uppercase;display:inline-block;margin:3px;">Strange Attractor</span><span style="font-family:'Share Tech Mono',monospace;font-size:9px;letter-spacing:2px;padding:4px 13px;border-radius:100px;border:1px solid #c040ff99;color:#c040ff;text-transform:uppercase;display:inline-block;margin:3px;">Fractal Geometry</span><span style="font-family:'Share Tech Mono',monospace;font-size:9px;letter-spacing:2px;padding:4px 13px;border-radius:100px;border:1px solid #c040ff99;color:#c040ff;text-transform:uppercase;display:inline-block;margin:3px;">Flame Rendering</span><span style="font-family:'Share Tech Mono',monospace;font-size:9px;letter-spacing:2px;padding:4px 13px;border-radius:100px;border:1px solid #c040ff99;color:#c040ff;text-transform:uppercase;display:inline-block;margin:3px;">Chaos Theory</span></div>
    </div>
  </div>
</div>'''))

# %%
from IPython.display import HTML, display
display(HTML('''<link href="https://fonts.googleapis.com/css2?family=Orbitron:wght@400;700;900&family=Share+Tech+Mono&family=Bebas+Neue&display=swap" rel="stylesheet">
<style>
@keyframes panelglow-cl{0%,100%{box-shadow:0 0 30px #c040ff16,inset 0 0 40px rgba(0,0,0,.4)}
  50%{box-shadow:0 0 55px #c040ff28,inset 0 0 55px rgba(0,0,0,.6)}}
@keyframes shimmer-cl{0%{left:-100%}100%{left:200%}}
</style>
<div style="position:relative;margin:16px 0 32px;overflow:hidden;
  background:linear-gradient(135deg,#07041a,#04020e 40%,#060320);
  border:1px solid #c040ff1e;border-radius:16px;padding:38px 36px 32px;
  animation:panelglow-cl 5s ease-in-out infinite;">
  <div style="position:absolute;top:0;left:-100%;width:60%;height:1px;pointer-events:none;
    background:linear-gradient(90deg,transparent,#c040ffbb,transparent);
    animation:shimmer-cl 5s ease-in-out infinite;"></div>
  <div style="position:absolute;top:14px;left:14px;width:22px;height:22px;
    border-top:2px solid #c040ff88;border-left:2px solid #c040ff88;border-radius:3px 0 0 0;"></div>
  <div style="position:absolute;top:14px;right:14px;width:22px;height:22px;
    border-top:2px solid #c040ff88;border-right:2px solid #c040ff88;border-radius:0 3px 0 0;"></div>
  <div style="position:absolute;bottom:14px;left:14px;width:22px;height:22px;
    border-bottom:2px solid #c040ff44;border-left:2px solid #c040ff44;border-radius:0 0 0 3px;"></div>
  <div style="position:absolute;bottom:14px;right:14px;width:22px;height:22px;
    border-bottom:2px solid #c040ff44;border-right:2px solid #c040ff44;border-radius:0 0 3px 0;"></div>
  <div style="position:absolute;top:-1px;left:50%;transform:translateX(-50%);
    background:#07041a;border:1px solid #c040ff33;border-top:none;
    padding:0 18px 5px;border-radius:0 0 8px 8px;">
    <span style="font-family:'Share Tech Mono',monospace;font-size:9px;letter-spacing:4px;
      color:#c040ff77;text-transform:uppercase;">&#9654; what is actually happening &#9664;</span>
  </div>
  <div style="margin-top:16px;">
    <div style="margin-bottom:30px;">
      <div style="display:flex;align-items:center;gap:12px;margin-bottom:14px;">
        <span style="font-size:18px;">🔮</span>
        <div style="flex:1;height:1px;background:linear-gradient(90deg,#c040ff44,transparent);"></div>
        <span style="font-family:'Orbitron',sans-serif;font-size:10px;font-weight:700;
          color:#c040ff;letter-spacing:3px;text-transform:uppercase;">The Rule</span>
        <div style="flex:1;height:1px;background:linear-gradient(270deg,#c040ff44,transparent);"></div>
      </div>
      <div style="font-family:'Share Tech Mono',monospace;font-size:13px;
        color:rgba(210,195,255,.68);line-height:2;">Take point (0.1, 0.1). Apply a rule. Record. Repeat <strong style='color:#c040ff;'>six million times</strong>. Zero randomness:<div style="background:#c040ff0d;border-left:3px solid #c040ff;border-radius:0 8px 8px 0;padding:12px 18px;margin:12px 0;font-size:13.5px;color:#c040ff;letter-spacing:.5px;line-height:2.1;">xₙ₊₁ = sin(a · yₙ) + c · cos(a · xₙ)<br>yₙ₊₁ = sin(b · xₙ) + d · cos(b · yₙ)</div>Four constants. The result looks hand-drawn and organic. It is neither.</div>
    </div>
    <div style="margin-bottom:30px;">
      <div style="display:flex;align-items:center;gap:12px;margin-bottom:14px;">
        <span style="font-size:18px;">🌀</span>
        <div style="flex:1;height:1px;background:linear-gradient(90deg,#c040ff44,transparent);"></div>
        <span style="font-family:'Orbitron',sans-serif;font-size:10px;font-weight:700;
          color:#c040ff;letter-spacing:3px;text-transform:uppercase;">Why Structure Emerges</span>
        <div style="flex:1;height:1px;background:linear-gradient(270deg,#c040ff44,transparent);"></div>
      </div>
      <div style="font-family:'Share Tech Mono',monospace;font-size:13px;
        color:rgba(210,195,255,.68);line-height:2;">The point is <strong style='color:#c040ff;'>trapped</strong>. It enters a bounded region — the <strong style='color:#c040ff;'>attractor set</strong> — and never escapes. Within it, the point never settles, never repeats, never stops. It wanders forever tracing the same ghostly skeleton.<br><br>The attractor has <strong style='color:#c040ff;'>fractal geometry</strong>: every tendril splits into finer tendrils. Its Hausdorff dimension is ~1.6 — not a whole number, between a curve (1D) and a filled region (2D).</div>
    </div>
    <div style="margin-bottom:0px;">
      <div style="display:flex;align-items:center;gap:12px;margin-bottom:14px;">
        <span style="font-size:18px;">🎨</span>
        <div style="flex:1;height:1px;background:linear-gradient(90deg,#c040ff44,transparent);"></div>
        <span style="font-family:'Orbitron',sans-serif;font-size:10px;font-weight:700;
          color:#c040ff;letter-spacing:3px;text-transform:uppercase;">Flame Fractal Rendering</span>
        <div style="flex:1;height:1px;background:linear-gradient(270deg,#c040ff44,transparent);"></div>
      </div>
      <div style="font-family:'Share Tech Mono',monospace;font-size:13px;
        color:rgba(210,195,255,.68);line-height:2;">A 2D histogram of counters — one per pixel — accumulates visit frequency over 6 million steps. A <strong style='color:#c040ff;'>logarithmic scale</strong> prevents bright ridges from washing out delicate filaments. Gamma correction then maps density to colour. This is <strong style='color:#c040ff;'>flame fractal rendering</strong>.<div style="background:#c040ff09;border:1px solid #c040ff28;border-radius:10px;padding:14px 18px;margin-top:14px;font-size:12px;color:rgba(220,210,255,.6);line-height:1.95;"><span style="color:#c040ff;font-weight:bold;">&#9670;</span> <strong>Purple</strong>: folded ribbon — bilateral near-symmetry, dense ridges. &nbsp;<strong>Green</strong>: branching tree — orbit fans into filaments. &nbsp;<strong>Red</strong>: collapsed spiral — dense core, sparse arms. Same equations. Three parameter sets.</div></div>
    </div></div>
</div>'''))

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
from matplotlib import animation
from IPython.display import HTML, display
import warnings; warnings.filterwarnings('ignore')

plt.rcParams.update({
    'figure.facecolor':'#03020a','axes.facecolor':'#03020a',
    'axes.edgecolor':'#1a0a30','text.color':'#c8b8ff',
    'axes.labelcolor':'#c8b8ff','xtick.color':'#5030a0',
    'ytick.color':'#5030a0','font.family':'monospace'
})

# %%
def clifford_pts(a,b,c,d,n=6_000_000):
    x,y=np.float32(.1),np.float32(.1)
    xs,ys=np.empty(n,np.float32),np.empty(n,np.float32)
    for i in range(n):
        xs[i]=x; ys[i]=y
        x,y=np.sin(a*y)+c*np.cos(a*x), np.sin(b*x)+d*np.cos(b*y)
    return xs,ys

def hrender(xs,ys,W=1000,H=700,g=.45):
    xr=xs.max()-xs.min(); yr=ys.max()-ys.min()
    ix=np.clip(((xs-xs.min())/(xr+1e-9)*(W-1)).astype(int),0,W-1)
    iy=np.clip(((ys-ys.min())/(yr+1e-9)*(H-1)).astype(int),0,H-1)
    h=np.zeros((H,W),np.float32); np.add.at(h,(iy,ix),1)
    h=np.log1p(h); h/=h.max(); return h**g

psets=[(-1.7,1.3,-0.1,-1.21,"a=-1.7  b=1.3\nc=-0.1  d=-1.21\n'Folded ribbon'"),
       (-1.4,-1.3,-1.5,-1.3,"a=-1.4  b=-1.3\nc=-1.5  d=-1.3\n'Branching tree'"),
       (1.5,-1.8,1.6,.9,"a=1.5  b=-1.8\nc=1.6  d=0.9\n'Collapsed spiral'")]
cmps=[LinearSegmentedColormap.from_list("c1",["#03020a","#1a0030","#6010c0","#c040ff","#fff"]),
      LinearSegmentedColormap.from_list("c2",["#03020a","#001a10","#006040","#00f5a0","#fff"]),
      LinearSegmentedColormap.from_list("c3",["#03020a","#200010","#800020","#ff4060","#fff"])]

fig,axes=plt.subplots(1,3,figsize=(24,8),facecolor='#03020a')
fig.subplots_adjust(left=.01,right=.99,top=.92,bottom=.03,wspace=.03)
for ax,(a,b,c,d,lb),cm in zip(axes,psets,cmps):
    print(f"  {lb.split(chr(10))[2]} ...",end=" ",flush=True)
    xs,ys=clifford_pts(a,b,c,d); h=hrender(xs,ys); print("done")
    ax.imshow(h,cmap=cm,origin='lower',aspect='auto',interpolation='bilinear')
    ax.set_title(lb,color='#c8b8ff',fontsize=9,pad=5); ax.axis('off')
fig.suptitle("CLIFFORD ATTRACTOR  ·  6M deterministic iterations  ·  flame fractal density render",
             color='#c040ff',fontsize=12,y=.97)
plt.show()
print("No randomness. No noise. Four numbers — infinite fractal structure.")
