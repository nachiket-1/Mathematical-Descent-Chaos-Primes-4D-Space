# %%
from IPython.display import HTML, display
display(HTML('''<link href="https://fonts.googleapis.com/css2?family=Orbitron:wght@400;700;900&family=Share+Tech+Mono&family=Bebas+Neue&display=swap" rel="stylesheet"><style>
@keyframes gpan{0%{background-position:0% 50%}50%{background-position:100% 50%}100%{background-position:0% 50%}}
@keyframes glitch1{0%,88%,100%{clip-path:none;transform:none}89%{clip-path:polygon(0 10%,100% 10%,100% 28%,0 28%);transform:translateX(-5px);filter:hue-rotate(80deg) brightness(2)}91%{clip-path:polygon(0 55%,100% 55%,100% 72%,0 72%);transform:translateX(5px);filter:hue-rotate(-50deg)}93%{clip-path:none;transform:none;filter:none}}
@keyframes glitch2{0%,93%,100%{opacity:0}90%{opacity:.9;transform:translateX(8px);filter:hue-rotate(200deg)}92%{opacity:.4;transform:translateX(-8px)}}
@keyframes scan{0%{transform:translateY(-100%)}100%{transform:translateY(120vh)}}
@keyframes ptag{0%,100%{box-shadow:0 0 8px currentColor;opacity:.7}50%{box-shadow:0 0 24px currentColor,0 0 50px currentColor;opacity:1}}
@keyframes flkr{0%,95%,100%{opacity:1}96%{opacity:.1}97%{opacity:.8}}
@keyframes flt{0%,100%{transform:translateY(0)}50%{transform:translateY(-10px)}}
@keyframes spinr{from{transform:rotate(0)}to{transform:rotate(360deg)}}
@keyframes spini{from{transform:rotate(0)}to{transform:rotate(-360deg)}}
</style>
<div style="position:relative;background:#03020a;padding:80px 40px 60px;border-radius:24px;
  text-align:center;overflow:hidden;border:1px solid rgba(140,60,255,.22);
  box-shadow:0 0 100px rgba(100,40,255,.14),inset 0 0 120px rgba(0,0,0,.8);">
  <div style="position:absolute;inset:0;pointer-events:none;
    background-image:linear-gradient(rgba(100,40,255,.06) 1px,transparent 1px),
      linear-gradient(90deg,rgba(100,40,255,.06) 1px,transparent 1px);
    background-size:52px 52px;"></div>
  <div style="position:absolute;inset:0;pointer-events:none;
    background:radial-gradient(ellipse 80% 60% at 50% 40%,rgba(100,40,255,.09),transparent 70%);"></div>
  <div style="position:absolute;left:0;right:0;height:2px;pointer-events:none;
    background:linear-gradient(90deg,transparent,rgba(180,100,255,.55),transparent);
    animation:scan 6s linear infinite;"></div>
  <div style="position:absolute;top:50%;left:50%;width:620px;height:620px;
    margin:-310px 0 0 -310px;border:1px solid rgba(120,60,255,.07);border-radius:50%;
    animation:spinr 40s linear infinite;pointer-events:none;">
    <span style="position:absolute;top:-9px;left:50%;transform:translateX(-50%);
      color:rgba(180,100,255,.4);font-size:11px;">&#9650;</span></div>
  <div style="position:absolute;top:50%;left:50%;width:420px;height:420px;
    margin:-210px 0 0 -210px;border:1px dashed rgba(80,200,255,.06);border-radius:50%;
    animation:spini 25s linear infinite;pointer-events:none;">
    <span style="position:absolute;bottom:-7px;left:50%;transform:translateX(-50%);
      color:rgba(80,200,255,.3);font-size:9px;">&#9679;</span></div>
  <div style="position:absolute;top:18px;left:18px;width:40px;height:40px;
    border-top:2px solid rgba(160,80,255,.55);border-left:2px solid rgba(160,80,255,.55);border-radius:3px 0 0 0;"></div>
  <div style="position:absolute;top:18px;right:18px;width:40px;height:40px;
    border-top:2px solid rgba(160,80,255,.55);border-right:2px solid rgba(160,80,255,.55);border-radius:0 3px 0 0;"></div>
  <div style="position:absolute;bottom:18px;left:18px;width:40px;height:40px;
    border-bottom:2px solid rgba(160,80,255,.35);border-left:2px solid rgba(160,80,255,.35);border-radius:0 0 0 3px;"></div>
  <div style="position:absolute;bottom:18px;right:18px;width:40px;height:40px;
    border-bottom:2px solid rgba(160,80,255,.35);border-right:2px solid rgba(160,80,255,.35);border-radius:0 0 3px 0;"></div>
  <p style="font-family:'Share Tech Mono',monospace;font-size:10px;letter-spacing:9px;
    color:rgba(160,100,255,.45);text-transform:uppercase;margin:0 0 24px;
    animation:flkr 8s infinite;">&#9658; &nbsp; mathematical descent &nbsp; &#9668;</p>
  <div style="position:relative;display:inline-block;margin-bottom:10px;">
    <div style="font-family:'Orbitron',sans-serif;font-size:clamp(36px,5.5vw,64px);font-weight:900;
      color:#c040ff;letter-spacing:5px;line-height:1.1;position:absolute;inset:0;
      animation:glitch2 14s ease infinite;opacity:0;user-select:none;">IMPOSSIBLE GEOMETRY</div>
    <h1 style="font-family:'Orbitron',sans-serif;font-size:clamp(36px,5.5vw,64px);font-weight:900;
      background:linear-gradient(90deg,#ff006e,#c040ff,#3a86ff,#00f5d4,#ffbe0b,#ff006e);
      background-size:300% 100%;-webkit-background-clip:text;-webkit-text-fill-color:transparent;
      background-clip:text;animation:gpan 5s ease infinite,glitch1 14s ease infinite;
      letter-spacing:5px;line-height:1.1;margin:0;position:relative;z-index:1;">IMPOSSIBLE GEOMETRY</h1>
  </div>
  <p style="font-family:'Share Tech Mono',monospace;font-size:11px;letter-spacing:6px;
    color:rgba(160,120,255,.4);text-transform:uppercase;margin:10px 0 28px;">
    three structures that shouldn&#39;t exist &mdash; but do</p>
  <p style="font-family:'Share Tech Mono',monospace;font-size:14px;color:rgba(210,190,255,.5);
    max-width:540px;margin:0 auto 36px;line-height:2.1;animation:flt 9s ease-in-out infinite;">
    Somewhere between a proof and a hallucination,<br>
    mathematics hides the most violent beauty<br>the universe has ever produced.</p>
  <div style="display:flex;justify-content:center;gap:10px;flex-wrap:wrap;position:relative;z-index:2;">
    <span style="font-family:'Share Tech Mono',monospace;font-size:9px;letter-spacing:2.5px;
      padding:5px 15px;border-radius:100px;border:1px solid #00f5d4;color:#00f5d4;
      text-transform:uppercase;animation:ptag 3.5s ease-in-out infinite;">Reaction-Diffusion</span>
    <span style="font-family:'Share Tech Mono',monospace;font-size:9px;letter-spacing:2.5px;
      padding:5px 15px;border-radius:100px;border:1px solid #c040ff;color:#c040ff;
      text-transform:uppercase;animation:ptag 3.5s ease-in-out .7s infinite;">Clifford Attractor</span>
    <span style="font-family:'Share Tech Mono',monospace;font-size:9px;letter-spacing:2.5px;
      padding:5px 15px;border-radius:100px;border:1px solid #ffbe0b;color:#ffbe0b;
      text-transform:uppercase;animation:ptag 3.5s ease-in-out 1.4s infinite;">Ulam Prime Spiral</span>
    <span style="font-family:'Share Tech Mono',monospace;font-size:9px;letter-spacing:2.5px;
      padding:5px 15px;border-radius:100px;border:1px solid #3a86ff;color:#3a86ff;
      text-transform:uppercase;animation:ptag 3.5s ease-in-out 2.1s infinite;">4D Tesseract</span>
  </div>
  <div style="width:240px;height:1px;margin:36px auto 0;
    background:linear-gradient(90deg,transparent,rgba(180,80,255,.7),transparent);"></div>
</div>'''))
# Out:
# <link href="https://fonts.googleapis.com/css2?family=Orbitron:wght@400;700;900&family=Share+Tech+Mono&family=Bebas+Neue&display=swap" rel="stylesheet"><style>
# @keyframes gpan{0%{background-position:0% 50%}50%{background-position:100% 50%}100%{background-position:0% 50%}}
# @keyframes glitch1{0%,88%,100%{clip-path:none;transform:none}89%{clip-path:polygon(0 10%,100% 10%,100% 28%,0 28%);transform:translateX(-5px);filter:hue-rotate(80deg) brightness(2)}91%{clip-path:polygon(0 55%,100% 55%,100% 72%,0 72%);transform:translateX(5px);filter:hue-rotate(-50deg)}93%{clip-path:none;transform:none;filter:none}}
# @keyframes glitch2{0%,93%,100%{opacity:0}90%{opacity:.9;transform:translateX(8px);filter:hue-rotate(200deg)}92%{opacity:.4;transform:translateX(-8px)}}
# @keyframes scan{0%{transform:translateY(-100%)}100%{transform:translateY(120vh)}}
# @keyframes ptag{0%,100%{box-shadow:0 0 8px currentColor;opacity:.7}50%{box-shadow:0 0 24px currentColor,0 0 50px currentColor;opacity:1}}
# ...

# %%
from IPython.display import HTML, display
display(HTML('''<link href="https://fonts.googleapis.com/css2?family=Orbitron:wght@400;700;900&family=Share+Tech+Mono&family=Bebas+Neue&display=swap" rel="stylesheet"><style>
@keyframes gpan{0%{background-position:0% 50%}50%{background-position:100% 50%}100%{background-position:0% 50%}}
@keyframes glitch1{0%,88%,100%{clip-path:none;transform:none}89%{clip-path:polygon(0 10%,100% 10%,100% 28%,0 28%);transform:translateX(-5px);filter:hue-rotate(80deg) brightness(2)}91%{clip-path:polygon(0 55%,100% 55%,100% 72%,0 72%);transform:translateX(5px);filter:hue-rotate(-50deg)}93%{clip-path:none;transform:none;filter:none}}
@keyframes glitch2{0%,93%,100%{opacity:0}90%{opacity:.9;transform:translateX(8px);filter:hue-rotate(200deg)}92%{opacity:.4;transform:translateX(-8px)}}
@keyframes scan{0%{transform:translateY(-100%)}100%{transform:translateY(120vh)}}
@keyframes ptag{0%,100%{box-shadow:0 0 8px currentColor;opacity:.7}50%{box-shadow:0 0 24px currentColor,0 0 50px currentColor;opacity:1}}
@keyframes flkr{0%,95%,100%{opacity:1}96%{opacity:.1}97%{opacity:.8}}
@keyframes flt{0%,100%{transform:translateY(0)}50%{transform:translateY(-10px)}}
@keyframes spinr{from{transform:rotate(0)}to{transform:rotate(360deg)}}
@keyframes spini{from{transform:rotate(0)}to{transform:rotate(-360deg)}}
</style>
<style>
@keyframes gpan{0%{background-position:0% 50%}50%{background-position:100% 50%}100%{background-position:0% 50%}}
@keyframes cardpulse-i{0%,100%{transform:translateY(0)}50%{transform:translateY(-4px)}}
</style>
<div style="text-align:center;padding:20px 0 40px;">
  <p style="font-family:'Share Tech Mono',monospace;font-size:11px;letter-spacing:6px;
    color:rgba(160,120,255,.5);text-transform:uppercase;margin-bottom:32px;">
    &#9658; &nbsp; navigate the series &nbsp; &#9668;</p>
  <div style="display:grid;grid-template-columns:repeat(auto-fit,minmax(260px,1fr));gap:20px;max-width:1100px;margin:0 auto;">

    <div style="background:linear-gradient(135deg,#040210,#020108);border:1px solid #00f5d425;
      border-radius:16px;padding:28px 24px;border-left:4px solid #00f5d4;
      box-shadow:0 0 30px #00f5d410;animation:cardpulse-i 6s ease-in-out infinite;">
      <div style="font-family:'Share Tech Mono',monospace;font-size:9px;letter-spacing:4px;
        color:#00f5d470;text-transform:uppercase;margin-bottom:10px;">01 &nbsp;&#183;&nbsp; file</div>
      <div style="font-family:'Orbitron',sans-serif;font-size:15px;font-weight:700;
        color:#00f5d4;letter-spacing:2px;margin-bottom:10px;line-height:1.3;">GRAY-SCOTT<br>REACTION-DIFFUSION</div>
      <div style="font-family:'Share Tech Mono',monospace;font-size:11px;
        color:rgba(200,245,220,.5);line-height:1.8;">How leopards got their spots<br>from pure mathematics</div>
      <div style="margin-top:16px;font-family:'Share Tech Mono',monospace;font-size:9px;
        color:#00f5d450;letter-spacing:2px;">01_gray_scott_reaction_diffusion.ipynb</div>
    </div>

    <div style="background:linear-gradient(135deg,#040210,#020108);border:1px solid #c040ff25;
      border-radius:16px;padding:28px 24px;border-left:4px solid #c040ff;
      box-shadow:0 0 30px #c040ff10;animation:cardpulse-i 6s ease-in-out .5s infinite;">
      <div style="font-family:'Share Tech Mono',monospace;font-size:9px;letter-spacing:4px;
        color:#c040ff70;text-transform:uppercase;margin-bottom:10px;">02 &nbsp;&#183;&nbsp; file</div>
      <div style="font-family:'Orbitron',sans-serif;font-size:15px;font-weight:700;
        color:#c040ff;letter-spacing:2px;margin-bottom:10px;line-height:1.3;">CLIFFORD<br>STRANGE ATTRACTOR</div>
      <div style="font-family:'Share Tech Mono',monospace;font-size:11px;
        color:rgba(210,190,255,.5);line-height:1.8;">6 million deterministic steps<br>painting with chaos</div>
      <div style="margin-top:16px;font-family:'Share Tech Mono',monospace;font-size:9px;
        color:#c040ff50;letter-spacing:2px;">02_clifford_attractor.ipynb</div>
    </div>

    <div style="background:linear-gradient(135deg,#040210,#020108);border:1px solid #ffbe0b25;
      border-radius:16px;padding:28px 24px;border-left:4px solid #ffbe0b;
      box-shadow:0 0 30px #ffbe0b10;animation:cardpulse-i 6s ease-in-out 1s infinite;">
      <div style="font-family:'Share Tech Mono',monospace;font-size:9px;letter-spacing:4px;
        color:#ffbe0b70;text-transform:uppercase;margin-bottom:10px;">03 &nbsp;&#183;&nbsp; file</div>
      <div style="font-family:'Orbitron',sans-serif;font-size:15px;font-weight:700;
        color:#ffbe0b;letter-spacing:2px;margin-bottom:10px;line-height:1.3;">ULAM<br>PRIME SPIRAL</div>
      <div style="font-family:'Share Tech Mono',monospace;font-size:11px;
        color:rgba(255,230,160,.5);line-height:1.8;">Primes hiding in diagonals<br>discovered by accident in 1963</div>
      <div style="margin-top:16px;font-family:'Share Tech Mono',monospace;font-size:9px;
        color:#ffbe0b50;letter-spacing:2px;">03_ulam_prime_spiral.ipynb</div>
    </div>

    <div style="background:linear-gradient(135deg,#040210,#020108);border:1px solid #3a86ff25;
      border-radius:16px;padding:28px 24px;border-left:4px solid #3a86ff;
      box-shadow:0 0 30px #3a86ff10;animation:cardpulse-i 6s ease-in-out 1.5s infinite;">
      <div style="font-family:'Share Tech Mono',monospace;font-size:9px;letter-spacing:4px;
        color:#3a86ff70;text-transform:uppercase;margin-bottom:10px;">04 &nbsp;&#183;&nbsp; file</div>
      <div style="font-family:'Orbitron',sans-serif;font-size:15px;font-weight:700;
        color:#3a86ff;letter-spacing:2px;margin-bottom:10px;line-height:1.3;">4D TESSERACT<br>ANIMATED</div>
      <div style="font-family:'Share Tech Mono',monospace;font-size:11px;
        color:rgba(180,210,255,.5);line-height:1.8;">A hypercube rotating in the<br>XW and YZ planes simultaneously</div>
      <div style="margin-top:16px;font-family:'Share Tech Mono',monospace;font-size:9px;
        color:#3a86ff50;letter-spacing:2px;">04_tesseract_4d.ipynb</div>
    </div>

  </div>
</div>'''))
# Out:
# <link href="https://fonts.googleapis.com/css2?family=Orbitron:wght@400;700;900&family=Share+Tech+Mono&family=Bebas+Neue&display=swap" rel="stylesheet"><style>
# @keyframes gpan{0%{background-position:0% 50%}50%{background-position:100% 50%}100%{background-position:0% 50%}}
# @keyframes glitch1{0%,88%,100%{clip-path:none;transform:none}89%{clip-path:polygon(0 10%,100% 10%,100% 28%,0 28%);transform:translateX(-5px);filter:hue-rotate(80deg) brightness(2)}91%{clip-path:polygon(0 55%,100% 55%,100% 72%,0 72%);transform:translateX(5px);filter:hue-rotate(-50deg)}93%{clip-path:none;transform:none;filter:none}}
# @keyframes glitch2{0%,93%,100%{opacity:0}90%{opacity:.9;transform:translateX(8px);filter:hue-rotate(200deg)}92%{opacity:.4;transform:translateX(-8px)}}
# @keyframes scan{0%{transform:translateY(-100%)}100%{transform:translateY(120vh)}}
# @keyframes ptag{0%,100%{box-shadow:0 0 8px currentColor;opacity:.7}50%{box-shadow:0 0 24px currentColor,0 0 50px currentColor;opacity:1}}
# ...

# %%
from IPython.display import HTML, display
display(HTML('''<link href="https://fonts.googleapis.com/css2?family=Orbitron:wght@400;700;900&family=Share+Tech+Mono&family=Bebas+Neue&display=swap" rel="stylesheet">
<style>
@keyframes oglow{0%,100%{text-shadow:0 0 12px #c040ff,0 0 30px #c040ff44}50%{text-shadow:0 0 40px #ff006e,0 0 90px #ff006e44}}
@keyframes oscan{0%{left:-100%}100%{left:200%}}
@keyframes cardglow{0%,100%{box-shadow:0 0 20px rgba(180,100,255,.1)}50%{box-shadow:0 0 40px rgba(180,100,255,.2)}}
@keyframes gpan{0%{background-position:0% 50%}50%{background-position:100% 50%}100%{background-position:0% 50%}}
</style>
<div style="position:relative;margin:60px 0 20px;overflow:hidden;
  background:linear-gradient(135deg,#03020a,#0a0320 55%,#03020a);
  border:1px solid rgba(120,50,255,.18);border-radius:20px;padding:60px 40px 50px;
  text-align:center;font-family:'Share Tech Mono',monospace;">
  <div style="position:absolute;inset:0;pointer-events:none;
    background-image:linear-gradient(rgba(100,40,255,.04) 1px,transparent 1px),
      linear-gradient(90deg,rgba(100,40,255,.04) 1px,transparent 1px);
    background-size:44px 44px;"></div>
  <div style="position:absolute;top:50%;left:-100%;width:50%;height:1px;pointer-events:none;
    background:linear-gradient(90deg,transparent,rgba(200,100,255,.5),transparent);
    animation:oscan 5s ease-in-out infinite;"></div>
  <div style="position:absolute;top:16px;left:16px;width:32px;height:32px;
    border-top:2px solid rgba(160,80,255,.5);border-left:2px solid rgba(160,80,255,.5);border-radius:3px 0 0 0;"></div>
  <div style="position:absolute;top:16px;right:16px;width:32px;height:32px;
    border-top:2px solid rgba(160,80,255,.5);border-right:2px solid rgba(160,80,255,.5);border-radius:0 3px 0 0;"></div>
  <div style="position:absolute;bottom:16px;left:16px;width:32px;height:32px;
    border-bottom:2px solid rgba(160,80,255,.3);border-left:2px solid rgba(160,80,255,.3);border-radius:0 0 0 3px;"></div>
  <div style="position:absolute;bottom:16px;right:16px;width:32px;height:32px;
    border-bottom:2px solid rgba(160,80,255,.3);border-right:2px solid rgba(160,80,255,.3);border-radius:0 0 3px 0;"></div>
  <h2 style="font-family:'Orbitron',sans-serif;font-size:28px;font-weight:900;color:#c040ff;
    letter-spacing:5px;animation:oglow 3s ease-in-out infinite;margin-bottom:16px;">THREE PROFOUND TRUTHS</h2>
  <p style="color:rgba(200,180,255,.5);font-size:13px;line-height:2.2;max-width:560px;margin:0 auto 40px;">
    Every structure in this notebook emerged from equations small enough to fit on a single line.<br>
    Complexity is not added &mdash; it is <em>unavoidable</em>.</p>
  <div style="display:grid;grid-template-columns:repeat(auto-fit,minmax(230px,1fr));gap:18px;margin-bottom:40px;">
    <div style="border:1px solid rgba(0,245,212,.2);border-radius:14px;padding:26px 20px;
      background:rgba(0,245,212,.04);animation:cardglow 4s ease-in-out infinite;">
      <div style="font-family:'Orbitron',sans-serif;font-size:36px;font-weight:900;
        background:linear-gradient(135deg,#00f5d4,#00aa88);-webkit-background-clip:text;
        -webkit-text-fill-color:transparent;margin-bottom:12px;">01</div>
      <div style="font-size:11px;color:rgba(200,245,220,.6);line-height:1.9;">
        Simple rules produce infinite complexity.<br>Chaos is not the absence of order —<br>it is order we cannot compress.</div>
    </div>
    <div style="border:1px solid rgba(192,64,255,.2);border-radius:14px;padding:26px 20px;
      background:rgba(192,64,255,.04);animation:cardglow 4s ease-in-out .15s infinite;">
      <div style="font-family:'Orbitron',sans-serif;font-size:36px;font-weight:900;
        background:linear-gradient(135deg,#c040ff,#7020aa);-webkit-background-clip:text;
        -webkit-text-fill-color:transparent;margin-bottom:12px;">02</div>
      <div style="font-size:11px;color:rgba(210,190,255,.6);line-height:1.9;">
        The universe has at least 4 dimensions.<br>Every object you have ever seen<br>is a shadow of something higher.</div>
    </div>
    <div style="border:1px solid rgba(255,190,11,.2);border-radius:14px;padding:26px 20px;
      background:rgba(255,190,11,.04);animation:cardglow 4s ease-in-out .3s infinite;">
      <div style="font-family:'Orbitron',sans-serif;font-size:36px;font-weight:900;
        background:linear-gradient(135deg,#ffbe0b,#aa8000);-webkit-background-clip:text;
        -webkit-text-fill-color:transparent;margin-bottom:12px;">03</div>
      <div style="font-size:11px;color:rgba(255,230,160,.6);line-height:1.9;">
        Primes are not random.<br>They obey a law no human has proved.<br>The Riemann Hypothesis still waits.</div>
    </div>
  </div>
  <div style="width:200px;height:1px;margin:0 auto 24px;
    background:linear-gradient(90deg,transparent,rgba(180,80,255,.6),transparent);"></div>
  <p style="font-size:10px;letter-spacing:5px;color:rgba(160,80,255,.3);text-transform:uppercase;margin:0;">
    &#9658; &nbsp; end of descent &nbsp; &#9668;</p>
</div>'''))
# Out:
# <link href="https://fonts.googleapis.com/css2?family=Orbitron:wght@400;700;900&family=Share+Tech+Mono&family=Bebas+Neue&display=swap" rel="stylesheet">
# <style>
# @keyframes oglow{0%,100%{text-shadow:0 0 12px #c040ff,0 0 30px #c040ff44}50%{text-shadow:0 0 40px #ff006e,0 0 90px #ff006e44}}
# @keyframes oscan{0%{left:-100%}100%{left:200%}}
# @keyframes cardglow{0%,100%{box-shadow:0 0 20px rgba(180,100,255,.1)}50%{box-shadow:0 0 40px rgba(180,100,255,.2)}}
# @keyframes gpan{0%{background-position:0% 50%}50%{background-position:100% 50%}100%{background-position:0% 50%}}
# </style>
# <div style="position:relative;margin:60px 0 20px;overflow:hidden;
#   background:linear-gradient(135deg,#03020a,#0a0320 55%,#03020a);
#   border:1px solid rgba(120,50,255,.18);border-radius:20px;padding:60px 40px 50px;
#   text-align:center;font-family:'Share Tech Mono',monospace;">
#   <div style="position:absolute;inset:0;pointer-events:none;
# ...
