# %%
from IPython.display import HTML, display
display(HTML('''<link href="https://fonts.googleapis.com/css2?family=Orbitron:wght@400;700;900&family=Share+Tech+Mono&family=Bebas+Neue&display=swap" rel="stylesheet"><style>
@keyframes gpan{0%{background-position:0% 50%}50%{background-position:100% 50%}100%{background-position:0% 50%}}
@keyframes glitch1{0%,88%,100%{clip-path:none;transform:none}89%{clip-path:polygon(0 10%,100% 10%,100% 28%,0 28%);transform:translateX(-5px);filter:hue-rotate(80deg) brightness(2)}91%{clip-path:polygon(0 55%,100% 55%,100% 72%,0 72%);transform:translateX(5px);filter:hue-rotate(-50deg)}93%{clip-path:none;transform:none;filter:none}}
@keyframes glitch2{0%,93%,100%{opacity:0}90%{opacity:.9;transform:translateX(8px);filter:hue-rotate(200deg)}92%{opacity:.4;transform:translateX(-8px)}}
@keyframes scan{0%{transform:translateY(-100%)}100%{transform:translateY(120vh)}}
@keyframes ptag{0%,100%{box-shadow:0 0 8px currentColor;opacity:.7}50%{box-shadow:0 0 24px currentColor,0 0 50px currentColor;opacity:1}}
@keyframes flkr{0%,95%,100%{opacity:1}96%{opacity:.1}97%{opacity:.8}}
@keyframes flt{0%,100%{transform:translateY(0)}50%{transform:translateY(-10px)}}
@keyframes spinr{from{transform:rotate(0)}to{transform:rotate(360deg)}}
@keyframes spini{from{transform:rotate(0)}to{transform:rotate(-360deg)}}
</style>
<div style="position:relative;background:#03020a;padding:36px 40px 30px;border-radius:16px;
  border:1px solid #00f5d422;box-shadow:0 0 60px #00f5d410;overflow:hidden;margin-bottom:8px;">
  <div style="position:absolute;inset:0;pointer-events:none;
    background-image:linear-gradient(#00f5d407 1px,transparent 1px),
      linear-gradient(90deg,#00f5d407 1px,transparent 1px);
    background-size:44px 44px;"></div>
  <div style="position:absolute;left:0;top:0;bottom:0;width:4px;
    background:linear-gradient(180deg,transparent,#00f5d4,#00f5d488,transparent);
    box-shadow:0 0 16px #00f5d4;"></div>
  <div style="padding-left:20px;">
    <div style="font-family:'Share Tech Mono',monospace;font-size:9px;letter-spacing:7px;
      color:#00f5d460;text-transform:uppercase;margin-bottom:8px;">
      IMPOSSIBLE GEOMETRY &nbsp;&#183;&nbsp; SECTION 01</div>
    <h1 style="font-family:'Orbitron',sans-serif;font-size:clamp(20px,2.5vw,32px);font-weight:900;
      letter-spacing:3px;margin:0;line-height:1.2;
      background:linear-gradient(90deg,#00f5d4,#ffffff,#00f5d4);
      background-size:200% 100%;-webkit-background-clip:text;-webkit-text-fill-color:transparent;
      background-clip:text;animation:gpan 5s ease infinite;">GRAY-SCOTT REACTION-DIFFUSION</h1>
  </div>
</div>'''))

# %%
from IPython.display import HTML, display
display(HTML('''<link href="https://fonts.googleapis.com/css2?family=Orbitron:wght@400;700;900&family=Share+Tech+Mono&family=Bebas+Neue&display=swap" rel="stylesheet">
<style>
@keyframes numglow-gs{0%,100%{opacity:.1;text-shadow:none}50%{opacity:.42;text-shadow:0 0 80px #00f5d4}}
@keyframes secin-gs{from{opacity:0;transform:translateX(-30px)}to{opacity:1;transform:translateX(0)}}
@keyframes bscan-gs{0%{transform:translateY(-100%)}100%{transform:translateY(500px)}}
@keyframes linefill-gs{from{width:0}to{width:100%}}
@keyframes gpan{0%{background-position:0% 50%}50%{background-position:100% 50%}100%{background-position:0% 50%}}
@keyframes ptag{0%,100%{box-shadow:0 0 8px currentColor;opacity:.7}50%{box-shadow:0 0 24px currentColor;opacity:1}}
</style>
<div style="position:relative;margin:52px 0 0;overflow:visible;">
  <div style="position:absolute;top:-28px;right:16px;z-index:0;pointer-events:none;user-select:none;
    font-family:'Bebas Neue',sans-serif;font-size:190px;line-height:1;color:#00f5d4;letter-spacing:-4px;
    animation:numglow-gs 4s ease-in-out infinite;">01</div>
  <div style="position:relative;z-index:1;
    background:linear-gradient(110deg,rgba(0,0,0,.92),rgba(8,3,20,.96) 50%,rgba(0,0,0,.85));
    border:1px solid #00f5d430;border-radius:4px 20px 20px 4px;
    padding:36px 200px 36px 0;overflow:hidden;
    box-shadow:0 0 60px #00f5d416,inset 0 0 80px rgba(0,0,0,.6);">
    <div style="position:absolute;left:0;top:0;bottom:0;width:6px;
      background:linear-gradient(180deg,#00ffaa,#00f5d4,#00ffaa);
      box-shadow:0 0 20px #00f5d4,0 0 40px #00f5d488;"></div>
    <div style="position:absolute;left:6px;right:0;height:1px;pointer-events:none;
      background:linear-gradient(90deg,#00f5d477,transparent);
      animation:bscan-gs 4.5s linear infinite;"></div>
    <div style="position:absolute;top:0;left:6px;height:1px;
      background:linear-gradient(90deg,#00f5d455,transparent);
      animation:linefill-gs 1.3s ease both;"></div>
    <div style="padding-left:36px;">
      <div style="font-family:'Share Tech Mono',monospace;font-size:10px;letter-spacing:6px;
        color:#00f5d480;text-transform:uppercase;margin-bottom:10px;
        animation:secin-gs .8s ease both;">SECTION &nbsp;01</div>
      <h2 style="font-family:'Orbitron',sans-serif;font-size:clamp(22px,3vw,36px);font-weight:900;
        letter-spacing:4px;margin:0 0 8px;line-height:1.15;
        background:linear-gradient(90deg,#00f5d4,#00ffaa,#ffffff,#00f5d4);
        background-size:250% 100%;-webkit-background-clip:text;-webkit-text-fill-color:transparent;
        background-clip:text;animation:gpan 6s ease infinite,secin-gs .9s ease both;">
        GRAY-SCOTT REACTION-DIFFUSION</h2>
      <p style="font-family:'Share Tech Mono',monospace;font-size:11px;letter-spacing:3px;
        color:rgba(210,190,255,.4);text-transform:uppercase;margin:0 0 20px;
        animation:secin-gs 1s ease both;">how leopards got their spots — from pure mathematics</p>
      <div style="display:flex;flex-wrap:wrap;"><span style="font-family:'Share Tech Mono',monospace;font-size:9px;letter-spacing:2px;padding:4px 13px;border-radius:100px;border:1px solid #00f5d499;color:#00f5d4;text-transform:uppercase;display:inline-block;margin:3px;">Turing Instability</span><span style="font-family:'Share Tech Mono',monospace;font-size:9px;letter-spacing:2px;padding:4px 13px;border-radius:100px;border:1px solid #00f5d499;color:#00f5d4;text-transform:uppercase;display:inline-block;margin:3px;">Activator-Inhibitor</span><span style="font-family:'Share Tech Mono',monospace;font-size:9px;letter-spacing:2px;padding:4px 13px;border-radius:100px;border:1px solid #00f5d499;color:#00f5d4;text-transform:uppercase;display:inline-block;margin:3px;">Morphogenesis</span><span style="font-family:'Share Tech Mono',monospace;font-size:9px;letter-spacing:2px;padding:4px 13px;border-radius:100px;border:1px solid #00f5d499;color:#00f5d4;text-transform:uppercase;display:inline-block;margin:3px;">PDE Simulation</span></div>
    </div>
  </div>
</div>'''))

# %%
from IPython.display import HTML, display
display(HTML('''<link href="https://fonts.googleapis.com/css2?family=Orbitron:wght@400;700;900&family=Share+Tech+Mono&family=Bebas+Neue&display=swap" rel="stylesheet">
<style>
@keyframes panelglow-gs{0%,100%{box-shadow:0 0 30px #00f5d416,inset 0 0 40px rgba(0,0,0,.4)}
  50%{box-shadow:0 0 55px #00f5d428,inset 0 0 55px rgba(0,0,0,.6)}}
@keyframes shimmer-gs{0%{left:-100%}100%{left:200%}}
</style>
<div style="position:relative;margin:16px 0 32px;overflow:hidden;
  background:linear-gradient(135deg,#07041a,#04020e 40%,#060320);
  border:1px solid #00f5d41e;border-radius:16px;padding:38px 36px 32px;
  animation:panelglow-gs 5s ease-in-out infinite;">
  <div style="position:absolute;top:0;left:-100%;width:60%;height:1px;pointer-events:none;
    background:linear-gradient(90deg,transparent,#00f5d4bb,transparent);
    animation:shimmer-gs 5s ease-in-out infinite;"></div>
  <div style="position:absolute;top:14px;left:14px;width:22px;height:22px;
    border-top:2px solid #00f5d488;border-left:2px solid #00f5d488;border-radius:3px 0 0 0;"></div>
  <div style="position:absolute;top:14px;right:14px;width:22px;height:22px;
    border-top:2px solid #00f5d488;border-right:2px solid #00f5d488;border-radius:0 3px 0 0;"></div>
  <div style="position:absolute;bottom:14px;left:14px;width:22px;height:22px;
    border-bottom:2px solid #00f5d444;border-left:2px solid #00f5d444;border-radius:0 0 0 3px;"></div>
  <div style="position:absolute;bottom:14px;right:14px;width:22px;height:22px;
    border-bottom:2px solid #00f5d444;border-right:2px solid #00f5d444;border-radius:0 0 3px 0;"></div>
  <div style="position:absolute;top:-1px;left:50%;transform:translateX(-50%);
    background:#07041a;border:1px solid #00f5d433;border-top:none;
    padding:0 18px 5px;border-radius:0 0 8px 8px;">
    <span style="font-family:'Share Tech Mono',monospace;font-size:9px;letter-spacing:4px;
      color:#00f5d477;text-transform:uppercase;">&#9654; what is actually happening &#9664;</span>
  </div>
  <div style="margin-top:16px;">
    <div style="margin-bottom:30px;">
      <div style="display:flex;align-items:center;gap:12px;margin-bottom:14px;">
        <span style="font-size:18px;">🧪</span>
        <div style="flex:1;height:1px;background:linear-gradient(90deg,#00f5d444,transparent);"></div>
        <span style="font-family:'Orbitron',sans-serif;font-size:10px;font-weight:700;
          color:#00f5d4;letter-spacing:3px;text-transform:uppercase;">The Setup</span>
        <div style="flex:1;height:1px;background:linear-gradient(270deg,#00f5d444,transparent);"></div>
      </div>
      <div style="font-family:'Share Tech Mono',monospace;font-size:13px;
        color:rgba(210,195,255,.68);line-height:2;">A flat surface coated in two invisible chemicals: <span style='color:#00f5d4;'>U</span> (prey) and <span style='color:#00f5d4;'>V</span> (predator). Both spread like ink in water but V diffuses <em>slower</em> than U. Two reactions happen simultaneously:<div style="background:#00f5d40d;border-left:3px solid #00f5d4;border-radius:0 8px 8px 0;padding:12px 18px;margin:12px 0;font-size:13.5px;color:#00f5d4;letter-spacing:.5px;line-height:2.1;">U + 2V → 3V &nbsp;&nbsp;&nbsp; (V converts U into more V — predator devours prey)<br>V → P &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; (V decays spontaneously — predator dies)</div>No biology, no randomness, no hand-drawn pattern. Two chemicals obeying physics.</div>
    </div>
    <div style="margin-bottom:30px;">
      <div style="display:flex;align-items:center;gap:12px;margin-bottom:14px;">
        <span style="font-size:18px;">⚛️</span>
        <div style="flex:1;height:1px;background:linear-gradient(90deg,#00f5d444,transparent);"></div>
        <span style="font-family:'Orbitron',sans-serif;font-size:10px;font-weight:700;
          color:#00f5d4;letter-spacing:3px;text-transform:uppercase;">The Equations</span>
        <div style="flex:1;height:1px;background:linear-gradient(270deg,#00f5d444,transparent);"></div>
      </div>
      <div style="font-family:'Share Tech Mono',monospace;font-size:13px;
        color:rgba(210,195,255,.68);line-height:2;">Two coupled <strong style='color:#00f5d4;'>partial differential equations</strong>:<div style="background:#00f5d40d;border-left:3px solid #00f5d4;border-radius:0 8px 8px 0;padding:12px 18px;margin:12px 0;font-size:13.5px;color:#00f5d4;letter-spacing:.5px;line-height:2.1;">∂U/∂t = Dᵤ∇²U − UV² + f(1 − U)<br>∂V/∂t = Dᵥ∇²V + UV² − (f + k)V</div>The <strong style='color:#00f5d4;'>Laplacian ∇²</strong> is the engine of diffusion — it measures how different each point is from its neighbours. The autocatalytic term <strong style='color:#00f5d4;'>UV²</strong> requires one U and two V molecules to collide, making growth nonlinear and producing structure.</div>
    </div>
    <div style="margin-bottom:0px;">
      <div style="display:flex;align-items:center;gap:12px;margin-bottom:14px;">
        <span style="font-size:18px;">💡</span>
        <div style="flex:1;height:1px;background:linear-gradient(90deg,#00f5d444,transparent);"></div>
        <span style="font-family:'Orbitron',sans-serif;font-size:10px;font-weight:700;
          color:#00f5d4;letter-spacing:3px;text-transform:uppercase;">Why Patterns Form — Turing Instability</span>
        <div style="flex:1;height:1px;background:linear-gradient(270deg,#00f5d444,transparent);"></div>
      </div>
      <div style="font-family:'Share Tech Mono',monospace;font-size:13px;
        color:rgba(210,195,255,.68);line-height:2;">In 1952, Alan Turing proved: if an activator spreads <em>slower</em> than its inhibitor, a tiny fluctuation will <strong style='color:#00f5d4;'>amplify rather than smooth out</strong>. A local excess of V grows before U can diffuse in to suppress it. The uniform state spontaneously collapses into peaks and troughs.<br><br>This is <strong style='color:#00f5d4;'>Turing instability</strong> — the mechanism behind leopard spots, zebrafish stripes, fingerprint whorls, coral branching, and hair follicle spacing. Biology did not design these patterns. The equations did.<div style="background:#00f5d409;border:1px solid #00f5d428;border-radius:10px;padding:14px 18px;margin-top:14px;font-size:12px;color:rgba(220,210,255,.6);line-height:1.95;"><span style="color:#00f5d4;font-weight:bold;">&#9670;</span> <strong>f</strong> = feed rate (U replenishment) &nbsp;|&nbsp; <strong>k</strong> = kill rate (V decay). These two numbers control everything. The 5 time-frames show V evolving from random seeds. The second plot runs identical equations with 4 different (f,k) pairs — each producing a completely different morphology.</div></div>
    </div></div>
</div>'''))

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
from matplotlib import animation
from IPython.display import HTML, display
import warnings; warnings.filterwarnings('ignore')

plt.rcParams.update({
    'figure.facecolor':'#03020a','axes.facecolor':'#03020a',
    'axes.edgecolor':'#1a0a30','text.color':'#c8b8ff',
    'axes.labelcolor':'#c8b8ff','xtick.color':'#5030a0',
    'ytick.color':'#5030a0','font.family':'monospace'
})

# %%
np.random.seed(42)
GRID, STEPS, Du, Dv = 300, 8000, 0.16, 0.08
f, k = 0.0545, 0.062   # coral regime

U = np.ones((GRID,GRID)); V = np.zeros((GRID,GRID))
for _ in range(18):
    cx,cy,r = np.random.randint(20,GRID-20),np.random.randint(20,GRID-20),np.random.randint(6,14)
    U[cy-r:cy+r,cx-r:cx+r] = 0.50+0.02*np.random.randn(2*r,2*r)
    V[cy-r:cy+r,cx-r:cx+r] = 0.25+0.01*np.random.randn(2*r,2*r)

def lap(X):
    return np.roll(X,1,0)+np.roll(X,-1,0)+np.roll(X,1,1)+np.roll(X,-1,1)-4*X

print("Running Gray-Scott (8 000 steps) ...", end=" ")
snaps=[]
for step in range(STEPS):
    uvv=U*V*V
    U+=Du*lap(U)-uvv+f*(1-U); V+=Dv*lap(V)+uvv-(f+k)*V
    U,V=np.clip(U,0,1),np.clip(V,0,1)
    if step in (500,1500,3000,5000,STEPS-1): snaps.append(V.copy())
print("done.")

cgs=LinearSegmentedColormap.from_list("gs",["#03020a","#0a1a2a","#003344","#00f5d4","#fff","#ff80ff","#c040ff","#1a0020"])

fig,axes=plt.subplots(1,5,figsize=(22,5),facecolor='#03020a')
fig.subplots_adjust(left=.01,right=.99,top=.86,bottom=.06,wspace=.03)
for ax,s,lb in zip(axes,snaps,["t=500\nearly branching","t=1500\ngrowth","t=3000\ncompetition","t=5000\nstabilising","t=8000\nfinal"]):
    ax.imshow(s,cmap=cgs,vmin=0,vmax=.4,interpolation='bilinear',origin='lower')
    ax.set_title(lb,color='#00f5d4',fontsize=8.5,pad=5); ax.axis('off')
fig.suptitle("GRAY-SCOTT  ·  V-concentration field  ·  f=0.0545  k=0.062  (coral regime)",color='#00f5d4',fontsize=12,y=.97)
plt.show()

configs=[(0.035,0.065,"Spots\nf=0.035  k=0.065"),(0.055,0.062,"Coral\nf=0.055  k=0.062"),
         (0.025,0.050,"Worm tunnels\nf=0.025  k=0.050"),(0.014,0.054,"Mitosis\nf=0.014  k=0.054")]
fig2,ax2=plt.subplots(1,4,figsize=(20,5),facecolor='#03020a')
fig2.subplots_adjust(left=.01,right=.99,top=.86,bottom=.06,wspace=.03)
for ax,(fi,ki,lb) in zip(ax2,configs):
    Ul=np.ones((180,180)); Vl=np.zeros((180,180))
    for _ in range(12):
        cx2,cy2=np.random.randint(15,165),np.random.randint(15,165)
        Ul[cy2-8:cy2+8,cx2-8:cx2+8]=0.5; Vl[cy2-8:cy2+8,cx2-8:cx2+8]=0.25
    for _ in range(6000):
        uvv2=Ul*Vl*Vl
        Ul+=Du*lap(Ul)-uvv2+fi*(1-Ul); Vl+=Dv*lap(Vl)+uvv2-(fi+ki)*Vl
        Ul,Vl=np.clip(Ul,0,1),np.clip(Vl,0,1)
    ax.imshow(Vl,cmap=cgs,vmin=0,vmax=.4,interpolation='bilinear',origin='lower')
    ax.set_title(lb,color='#00f5d4',fontsize=9,pad=5); ax.axis('off')
fig2.suptitle("SAME EQUATIONS  ·  FOUR (f,k) PAIRS  ·  INFINITE VARIETY",color='#00f5d4',fontsize=12,y=.97)
plt.show()
print("Every pattern above is identical physics. Only f and k changed.")
